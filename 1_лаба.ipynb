# %% [markdown]
# # **ЛАБОРАТОРНАЯ РАБОТА № 1**

# %% [markdown]
# # **Первая программа**
#
# ---

# %% [markdown]
# Напишите в строке IN:
#
# print ('hello world')
#
# нажмите Ctrl + Enter

# %%
print ('hello world')
#Это строка IN. здесь можно писать Ваш код. После знака # идет комментарий, который никак не влияет на выполнение кода, но позволяет программисту дать пояснение коду.
# Out:
# hello world

# %% [markdown]
# ![изображение_2023-02-03_001439108.png](data:image/png;base64,...)

# %% [markdown]
# Описание функции print в официальной документации Python.https://docs.python.org/3/library/functions.html#print
#
# Статья «Функции Print() в Python».
# https://www.internet-technologies.ru/articles/funkcii-print-v-python.html

# %% [markdown]
# 1. Сколько аргументов можно передавать в функцию для вывода на экран?
# 2. Как передать в функцию для вывода на экран несколько аргументов?
# 3. Что будет результатом выполнения команды print ('Hello' + 'World!')?

# %% [markdown]
# # **1. Основные математические действия в Python**
#
# ---

# %% [markdown]
# Знак в выражении (например, "плюс" или "минус") в Python называется оператором. Основные операторы перечислены в таблице ниже. Среди них особое внимание нужно уделить последним трём, поскольку их синтаксис может быть непривычным.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Упражнение 1.1. Напишите в каждой строчке по 1 примеру

# %% [markdown]
# Сложить:

# %%
2+3
# Out:
# 5

# %% [markdown]
# Вычесть:

# %%
2-3
# Out:
# -1

# %% [markdown]
# Умножить:

# %%
2*3
# Out:
# 6

# %% [markdown]
# Разделить:

# %%
2/3
# Out:
# 0.6666666666666666

# %% [markdown]
# Получить целую часть от деления:

# %%
2 // 3
# Out:
# 0

# %% [markdown]
# Получить остаток от деления:

# %%
4 % 3
# Out:
# 1

# %% [markdown]
# Возвести в степень

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# Упражнение 1.2.
#
# Задача 1. Использую основные матетические действия в Python, найдите, чему равен Х в этом уравнении:
#
#
# ![image.png](data:image/png;base64,...)

# %%
(67+33)*(25-20)/25
# Out:
# 20.0

# %% [markdown]
# Правильный ответ для проверки: 20

# %% [markdown]
# Задача 2. Вычислите:
#
#
# ![image.png](data:image/png;base64,...)

# %%
from math import sqrt

sqrt(4 + 5*60 - 17 + 65/4)
# Out:
# 17.414074767267998

# %% [markdown]
# Правильный ответ для проверки: 17.414074767267998

# %% [markdown]
# Задача 3. Вычислите:
#
#
# ![image.png](data:image/png;base64,...)

# %%
6.996+45*(13/2)**2+2*(18**0.5)
# Out:
# 1916.7312813742387

# %% [markdown]
# Правильный ответ для проверки:1916.7312813742387

# %% [markdown]
# Задача 4. Вычислите:
#
#
# ![image.png](data:image/png;base64,...)

# %%
chislitel = 1267 - 20 * (5**3/2)**2
znamenatel = 8**5 * sqrt(36)
chislitel/znamenatel
# Out:
# -0.3909200032552083

# %% [markdown]
# Правильный ответ для проверки:-0.3909200032552083

# %% [markdown]
# Задача 5. Вычислите:
#
#
# ![image.png](data:image/png;base64,...)

# %%
((sqrt(9)**3)**2)**2 / (-2)**(-3)
# Out:
# -4251528.0

# %% [markdown]
# Правильный ответ для проверки: -4251528.0

# %% [markdown]
# # **2. Переменные. Типы int, float и str**
#
# ---

# %% [markdown]
# В Python вы можете хранить значения в переменных.
#
# Например,

# %%
a = 5
my_name = "Слава"

# %% [markdown]
# Выражения
# Если в переменных лежат числа, то их можно складывать, вычитать, умножать, одним словом, делать все то же, что и с числами.
#
# Например,

# %%
a = 10
b = 15
c = a + b #присвоить значение С результат сложения a и b

# %% [markdown]
# В результате значение переменной c будет 25.
#
# # **Правила наименования переменных**
# Есть несколько правил при определении переменных:
#
# имена переменных не должны повторять уже встроенные в Python имена, например, print, str, in и т.д.;
#
# имена переменных могут содержать только буквы, цифры и нижнее подчёркивание;
# имена переменных не должны начинаться с цифры;
#
# очень желательно, чтобы имена переменных выражали суть переменной и не были слишком длинными.
# # **Типы переменных**
# В зависимости от нашей задачи нам придется сохранять в переменных разные типы значений. И соответственно, тип переменной зависит от того, какие значения там лежат.
#
# Давайте приведем пример. Нам нужно указать, сколько сотрудников работает в нашей компании.
#
# Создадим переменную employees_count и передадим ей значение 125 (столько сотрудников работает в ООО “Питонисты”)

# %%
employees_count = 125

# %% [markdown]
# В этом случае мы столкнулись с целым числом, и в Python ему соответствует тип int.
#
# Другой пример: мы хотим сохранить в переменной текущую температуру в комнате.
#
# Для этого создадим переменную room_temp и присвоим ей значение 20.4. В этом случае мы столкнулись с вещественным числом, и ему в Python соответствует тип переменной float.

# %% [markdown]
# Упражнение 2.1
# Присвойте переменной a значение 1000

# %%
a = 1000

# %% [markdown]
# Упражнение 2.2
# Создайте переменную room_temp и присвойте ей значение 20.4

# %%
room_temp = 20.4

# %% [markdown]
# # **3. Приведение типов переменных**
#
# ---

# %% [markdown]
# Если вы хотите понять, какой тип переменной перед вами, вы можете воспользоваться встроенной функцией type(). Например,
# type("Питонисты")
# Результатом будет str.

# %% [markdown]
# Чтобы перевести переменную из одного типа в другой, можно воспользоваться соответствующими функциями str(), int(), float(). В этом случае переменная поменяет тип. Например,a = float(2)
# Значение a будет 2.0

# %% [markdown]
# Упражнение 3.1
# Дана переменная типа float:

# %%
agent_name = 7.0

# %% [markdown]
# Напишите код, с помощью которого можно привести хранящееся в данной переменной значение к типу int. Ответ запишите в одну строку без пробелов. Не присваивайте результат приведения какой-либо переменной.

# %%
int(agent_name)
# Out:
# 7

# %% [markdown]
# Напишите код, с помощью которого можно привести хранящееся в данной переменной значение к типу str. Ответ запишите в одну строку без пробелов. Не присваивайте результат приведения какой-либо переменной.

# %%
str(agent_name)
# Out:
# '7.0'

# %% [markdown]
# # **4. Операции с переменными**
#
# ---

# %% [markdown]
# Как мы уже говорили, с переменными типами int и float можно применять все операции, пройденные нами ранее.
#
# Важно держать в голове следующие правила работы с типами:
#
# если хотя бы одна из переменных принадлежит к типу float, результат вычисления тоже получит тип float;
# при операции деления результат всегда вернётся с типом float, даже если оба исходных числа принадлежат к типу int.
# К строковым (текстовым) переменным, как ни странно, тоже применимы некоторые из изученных операторов — это операторы + и *.  Так, оператор + «склеит» воедино две строки, а оператор * продублирует строку нужное количество раз, объединив результат в одну строку.

# %% [markdown]
# Упражнение 4.1
# Какое значение выдаст Python для фрагментов кода, представленных ниже? используйте строку IN ниже для проверке результатов вычислений

# %% [markdown]
# 'hey'+'!'

# %% [markdown]
# type(2+3.4)

# %% [markdown]
# type(2+3)

# %%
# hey!
# <class 'float'>
# <class 'int'>

# %% [markdown]
# Контрольные вопросы для самопроверки:
# 1. К какому типу будет принадлежать результат выполнения операции 5 + 7.0?
# 2. К какому типу будет принадлежать результат применения такой функции: str(int(float('2.4')))?
# 3. К какому типу будет принадлежать результат выполнения операции 4 ** (1/2)?
# 4. Какой из кодов выполнится корректно, без ошибки?
# а)'42' + 2  б)'42'х 2  в)'42'^2 г)'42'/2
# 5. Каким будет результат выполнения функции type('I' + 'love' + 'Python')?

# %%
# float
# str
# float
# -
# IlovePython

# %% [markdown]
# # **5. Ввод данных с клавиатуры. Первые задачи по программированию**
#
# ---

# %% [markdown]
# В Python мы можем позволить пользователю вводить свои данные с клавиатуры: для этого существует встроенная функция **input()**.
#
# При использовании функции **input()** появляется окно для ввода, после заполнения которого пользователю необходимо нажать Enter.
#
# Аргумент этой функции можно оставить пустым, а можно добавить в него сопроводительную фразу (в кавычках), что именно должен ввести пользователь.
#
# Если не присваивать введённые пользователем данные никакой переменной, то они просто выведутся на экране, а если присвоить, сохранятся под именем переменной, но не выведутся на экран.
#
# В этом случае необходимо отдельно вызвать переменную.

# %%
input ('Напишите что-нибудь хорошее: ')

# %% [markdown]
# Напишите что-нибудь хорошее:
#
# Ввод: Я уже близок к тому, чтобы подружиться с Python!
#
# Вывод: 'Я уже близок к тому, чтобы подружиться с Python!'

# %%
phrase = input ('Напишите что-нибудь хорошее: ') #переменной phrase будет присвоено значение введенное в открывающемся окне

# %% [markdown]
# Ввод: Я уже близок к тому, чтобы подружиться с Python!

# %% [markdown]
# ! **Введённые пользователем через input() данные всегда рассматриваются как строковые (имеют тип string), даже в том случае, когда он вводит числа.**

# %% [markdown]
# Убедитесь в этом, запустив пример ниже

# %%
x = input("введите число x: ")
y = input("введите число y: ")
sum=x+y
print(sum) #выведет результат сложения x и y
type(sum) #покажет тип переменной
# Out:
# 123654
# str

# %% [markdown]
# # **Примеры задач, которые можно решить с помощью функции input**

# %% [markdown]
# Пример 1: Программа, которая просит пользователя ввести его имя и сохраняет результат в переменную user_name.

# %% [markdown]
# user_name = input('Введите своё имя: \n')
#
# \n — это знак для перемещения окна ввода на следующую строку!

# %%
user_name = input('Как вас зовут?\n')

# %% [markdown]
# Пример 2: Программа, которая умножает 5 на целочисленный множитель, введённый пользователем.

# %% [markdown]
# multiplier = int(input('Введите множитель для числа 5: \n'))
#
# print(5*multiplier)

# %%
multiplier = int(input('Укажите множитель: '))
print(5*multiplier)
# Out:
# 50

# %% [markdown]
# Пример 3: Программа, которая получает на вход два числа, a и b, и выводит на экран число a в степени b.

# %% [markdown]
# В функции print() можно в качестве аргументов перечислять через запятую все нужные для вывода данные
#
# a = float(input('Введите основание степени: \n'))
#
# b = float(input('Введите показатель степени: \n'))
#
# print('Полученное число:', a**b)

# %%
a = int(input('Основание степени = '))
b = int(input('Показатель = '))
print(a**b)
# Out:
# 32

# %% [markdown]
# # **ЗАДАНИЯ**
#
# ---

# %% [markdown]
# Задание 1
#
# Напишите программу, которая просит пользователя ввести своё имя в переменную **name**, а затем выводит на экран фразу: "Сегодня Вас зовут ...", где вместо многоточия отображается имя пользователя. Вместо name = input() используйте name = 'Алексей' для проверки.
#
# Пояснения:
#
# Чтобы вывести строку в нужном формате, можно либо перечислять то, что нужно вывести на экран, внутри функции print(): print('Привет,', name), либо складывать строки, например: print('Привет, ' + name).
#
# Обратите внимание на использование пробелов в строке, которая будет выводиться на экран с помощью функции print(): между каждой парой слов должен быть только один пробел; в начале и в конце выводимой на экран строки пробелов быть не должно; перед запятой пробел не ставится, после — ставится один пробел.

# %%
name = 'Алексей'
print('Сегодня Вас зовут', name)
# Out:
# Сегодня Вас зовут Алексей

# %% [markdown]
# Задание 2
#
#
# Напишите программу, которая выводит на экран длину слова, значение которого хранится в переменной word. Вместо word = input() используйте word = 'Очаровательно' для проверки.
#
# Подсказка №1: Длину слова (и не только слова) в Python можно узнать с помощью функции len().
#
# Подсказка №2: Программа должна вывести на экран только одно число, равное количеству символов в заданном слове.

# %%
word = 'Очаровательно'
print(len(word))
# Out:
# 13

# %% [markdown]
# Задание 3
#
#
# Напишите программу, которая принимает на вход два целых числа (a и b) и выводит на экран остаток от деления первого числа (а) на второе (b).
#
# Вместо a = int(input()) и b = int(input()) используйте a = 117 и b = 23.

# %%
print(117%23)
# Out:
# 2

# %% [markdown]
# Задание 4
#
# Напишите программу, с помощью которой пользователь может ввести три положительных числа и увидеть на экране их среднее геометрическое. Названия переменных a, b, c. Для теста используйте значения a=12, b=17, c=25
#
# Среднее геометрическое N чисел - это корень N-ной степени из произведения этих чисел.

# %%
print((12+17+25)/3)
# Out:
# 18.0

# %% [markdown]
# Задание 5
#
# Пусть дана следующая функция.
#
# ![image.png](data:image/png;base64,...)
#
# Напишите программу, с помощью которой пользователь может рассчитать значение функции, предварительно указав значение аргумента (x). Для проверок используйте x = 100500

# %%
def f(x):
    return 6.996 + 45 * (x/2)**2 + 2*x

print(f(int(input())))
# Out:
# 113628013506.996

# %% [markdown]
# Задание 6
#
# Напишите программу, с помощью которой пользователь сможет рассчитать свой индекс массы тела (масса тела в килограммах, делённая на квадрат роста в метрах). Выведите ИМТ на экран. Названия переменных weight и height. Для теста используйте значения weight=80, height = 1.8

# %%
weight = int(input('Ваш вес: '))
height = float(input('Ваш рост: '))
print('ИМТ = ', weight / height**2)
# Out:
# ИМТ =  24.691358024691358

# %% [markdown]
# Задание 7
#
# Напишите программу, которая принимает на вход два числа (a и b) и выводит корень третьей степени их среднего арифметического на экран.
#
# Вместо a = float(input()) и b = float(input()) используйте значения a = 270, b = 12.8

# %%
def avg(nums):
    return sum(nums)/len(nums)

a, b = float(input()), float(input())
print(avg([a, b])**(3/2))
# Out:
# 1681.41189004955

# %% [markdown]
# Задание 8
#
# Напишите программу, которая принимает на вход целое число, умножает его на 3 и выводит на экран сообщение: "Вы ввели число, которое при умножении на 3 даёт ...". В сообщении вместо многоточия должен быть отображён результат умножения в виде целого числа.
#
# Вместо a = int(input()) укажите значение a = 23 и не меняйте значение переменной в ходе выполнения кода.

# %%
print('Вы ввели число которое при умножении на 3 даёт число', 3*float(input()))
# Out:
# Вы ввели число которое при умножении на 3 даёт число 38.400000000000006

# %% [markdown]
# Задание 9
#
# Напишите программу, которая на вход принимает 3 строки и выводит на экран среднее геометрическое длин этих строк. Названия переменных string_1, string_2, string_3.
#
# Для теста используйте значения string_1 = 'Hello, world!', string_2 = 'Python <3', string_3 = 'qwerty'

# %%
def geometric_mean(numbers):
    product = 1
    for num in numbers:
        product *= num
    return product ** (1/len(numbers))

s = tuple(len(input()) for _ in range(3))
print(geometric_mean(s))
# Out:
# 3.1072325059538586

# %% [markdown]
# Задание 10
#
# Напишите программу, которая принимает на вход строку и целое число и выводит на экран эту строку, её длину и её длину в степени введённого целого числа. При введении, например, строки "привет" и числа "2" на экране должно быть выведено "привет 6 36". Названия переменной string, power. Для теста используйте значения string = 'Привет!', power = 5

# %%
x = input()
print(x, len(x), len(x)**2)
# Out:
# привет 6 36
